# %%
import streamlit as st
import streamlit as st
from streamlit_jupyter import StreamlitPatcher
StreamlitPatcher().jupyter()

# %%
st.title("Webリサーチエージェント")
st.write("Hello from Streamlit!")
st.button("Click me!")
# Out:
# # Webリサーチエージェント
# Hello from Streamlit!
# 2025-11-16 03:10:03.845 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:10:03.846 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:10:03.846 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:10:03.847 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:10:03.943
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/ryoyamasuda/Documents/git_repo_RyoyaMasuda/agent-book/chapter4/.venv/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-11-16 03:10:03.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:10:03.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# False

# %%
# !streamlit run /home/ryoyamasuda/Documents/git_repo_RyoyaMasuda/agent-book/chapter4/.venv/lib/python3.12/site-packages/ipykernel_launcher.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.11.15:8501
#
# NOTE: When using the `ipython kernel` entry point, Ctrl-C will not work.
#
# To exit, you will have to explicitly quit this process, by either sending
# "quit" from a client, or using Ctrl-\ in UNIX-like environments.
#
# To read more about this, see https://github.com/ipython/ipython/issues/2049
#
#
# To connect another client to this kernel, use:
#     --existing kernel-50420.json
# [IPKernelApp] ERROR | Unable to initialize signal:
# Traceback (most recent call last):
#   File "/home/ryoyamasuda/Documents/git_repo_RyoyaMasuda/agent-book/chapter4/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 720, in initialize
#     self.init_signal()
#   File "/home/ryoyamasuda/Documents/git_repo_RyoyaMasuda/agent-book/chapter4/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 556, in init_signal
#     signal.signal(signal.SIGINT, signal.SIG_IGN)
#   File "/home/ryoyamasuda/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/signal.py", line 58, in signal
#     handler = _signal.signal(_enum_to_int(signalnum), _enum_to_int(handler))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: signal only works in main thread of the main interpreter
# [IPKernelApp] WARNING | Config option `tqdm` not recognized by `IPKernelApp`.

# %%
import streamlit as st
from streamlit_jupyter import StreamlitPatcher

StreamlitPatcher().jupyter()

st.title("My Streamlit App in Jupyter")
st.write("Hello from Streamlit!")
# Out:
# 2025-11-16 03:04:07.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:04:07.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:04:07.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:04:07.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:04:07.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-16 03:04:07.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
